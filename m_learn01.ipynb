# %% [markdown]
# <a href="https://colab.research.google.com/github/oxcracx/ml-learn/blob/main/m_learn01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PLaying around with Collab.**

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data-sets/earthquake_data_tsunami.csv')
display(df.head())
# Out:
#    magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0        7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1        6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2        7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3        7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4        6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
#
#    Year  Month  tsunami
# 0  2022     11        1
# 1  2022     11        0
# 2  2022     11        1
# 3  2022     11        1
# 4  2022     11        1

# %% [markdown]
# ## Explore the data
#
# Let's take a look at the first few rows of the DataFrame and check the data types of the columns to get an overview of the dataset.

# %% [markdown]
# ## Count earthquakes by year
#
# Let's count how many earthquakes occurred in each year in the dataset.

# %%
# Display the head of the DataFrame
display(df.head())

# Display the column names and their data types
display(df.info())
# Out:
#    magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0        7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1        6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2        7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3        7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4        6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
#
#    Year  Month  tsunami
# 0  2022     11        1
# 1  2022     11        0
# 2  2022     11        1
# 3  2022     11        1
# 4  2022     11        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  782 non-null    float64
#  1   cdi        782 non-null    int64
#  2   mmi        782 non-null    int64
#  3   sig        782 non-null    int64
#  4   nst        782 non-null    int64
#  5   dmin       782 non-null    float64
#  6   gap        782 non-null    float64
#  7   depth      782 non-null    float64
#  8   latitude   782 non-null    float64
#  9   longitude  782 non-null    float64
#  10  Year       782 non-null    int64
#  11  Month      782 non-null    int64
#  12  tsunami    782 non-null    int64
# dtypes: float64(6), int64(7)
# memory usage: 79.6 KB
# None

# %%
earthquakes_by_year = df['Year'].value_counts().sort_index()
display(earthquakes_by_year)
# Out:
# Year
# 2001    28
# 2002    25
# 2003    31
# 2004    32
# 2005    28
# 2006    26
# 2007    37
# 2008    25
# 2009    26
# 2010    41
# 2011    34
# 2012    31
# 2013    53
# 2014    48
# 2015    53
# 2016    43
# 2017    36
# 2018    43
# 2019    33
# 2020    27
# 2021    42
# 2022    40
# Name: count, dtype: int64

# %% [markdown]
# ## Visualize Earthquake Locations on a Map
#
# Let's visualize the locations of the earthquakes on an interactive map using `Folium`.

# %% [markdown]
# ## Bar plot of earthquakes by year
#
# Now, let's visualize the number of earthquakes per year using a bar plot.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
earthquakes_by_year.plot(kind='bar')
plt.title('Number of Earthquakes by Year')
plt.xlabel('Year')
plt.ylabel('Number of Earthquakes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import folium

# Create a base map centered around a general area where earthquakes occur frequently
# You can adjust the location and zoom level as needed
m = folium.Map(location=[0, 0], zoom_start=2)

# Add markers for each earthquake location
for index, row in df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Magnitude: {row['magnitude']}, Depth: {row['depth']}"
    ).add_to(m)

# Display the map
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_945525b080bd2a815079276fba2fa861 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_945525b080bd2a815079276fba2fa861&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_945525b080bd2a815079276fba2fa861 = L.map(
#                 &quot;map_945525b080bd2a815079276fba2fa861&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b003aac172135224d12060044263de44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b003aac172135224d12060044263de44.addTo(map_945525b080bd2a815079276fba2fa861);
#
#
#             var marker_dd68436bf0c1d5e5855d2fdbd158ea9b = L.marker(
#                 [-9.7963, 159.596],
#                 {
# }
#             ).addTo(map_945525b080bd2a815079276fba2fa861);
#
#
#         var popup_6ccbd34dad3b64e483fc60ee38579a03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5649b232cde47f47452e24937f7c117 = $(`&lt;div id=&quot;html_e5649b232cde47f47452e24937f7c117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 7.0, Depth: 14.0&lt;/div&gt;`)[0];
#                 popup_6ccbd34dad3b64e483fc60ee38579a03.setContent(html_e5649b232cde47f47452e24937f7c117);
#
#
#
#         marker_dd68436bf0c1d5e5855d2fdbd158ea9b.bindPopup(popup_6ccbd34dad3b64e483fc60ee38579a03)
#         ;
#
#
#
#
#             var marker_ab8af58fa70def0c63e92d94c2c7f5db = L.marker(
#                 [-4.9559, 100.738],
#                 {
# }
#             ).addTo(map_945525b080bd2a815079276fba2fa861);
#
#
#         var popup_9840f19eb7709f2a7f1dee82fd5f1903 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7fddccc508cee7c9c976ed2848118f6 = $(`&lt;div id=&quot;html_b7fddccc508cee7c9c976ed2848118f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 6.9, Depth: 25.0&lt;/div&gt;`)[0];
#                 popup_9840f19eb7709f2a7f1dee82fd5f1903.setContent(html_b7fddccc508cee7c9c976ed2848118f6);
#
#
#
#         marker_ab8af58fa70def0c63e92d94c2c7f5db.bindPopup(popup_9840f19eb7709f2a7f1dee82fd5f1903)
#         ;
#
#
#
#
#             var marker_219ee8150cca32c7b1e3fa4bb02238d6 = L.marker(
#                 [-20.0508, -178.346],
#                 {
# }
#             ).addTo(map_945525b080bd2a815079276fba2fa861);
#
#
#         var popup_e5ee180770f67ff410032b97bfbe67f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee006008d2da8f161eca2206e237fd4c = $(`&lt;div id=&quot;html_ee006008d2da8f161eca2206e237fd4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 7.0, Depth: 579.0&lt;/div&gt;`)[0];
#                 popup_e5ee180770f67ff410032b97bfbe67f2.setContent(html_ee006008d2da8f161eca2206e237fd4c);
#
#
#
#         marker_219ee8150cca32c7b1e3fa4bb02238d6.bindPopup(popup_e5ee180770f67ff410032b97bfbe67f2)
#         ;
#
#
#
#
#             var marker_9a22d69e86029bfa94a8ab75377bcd67 = L.marker(
#                 [-19.2918, -172.129],
#                 {
# }
#             ).addTo(map_945525b080bd2a815079276fba2fa861);
#
#
#         var popup_e44fd78f02f85c5bb9277b6fab02932d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2dc946282620248051946551f185476 = $(`&lt;div id=&quot;html_e2dc946282620248051946551f185476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 7.3, Depth: 37.0&lt;/div&gt;`)[0];
#                 popup_e44fd78f02f85c5bb9277b6fab02932d.setContent(html_e2dc946282620248051946551f185476);
#
#
#
#         marker_9a22d69e86029bfa94a8ab75377bcd67.bindPopup(popup_e44fd78f02f85c5bb9277b6fab02932d)
#         ;
#
#
#
#
#             var marker_406b1efd73bfe9028a213a88f892a58f = L.marker(
#                 [-25.5948, 178.278],
#                 {
# }
#             ).addTo(map_945525b080bd2a815079276fba2fa861);
#
#
#         var popup_67651f4655bd7fc01d218ad848061892 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08eb27a6c69a11f9c18bb62474a66974 = $(`&lt;div id=&quot;html_08eb27a6c69a11f9c18bb62474a66974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 6.6, Depth: 624.464&lt;/div&gt;`)[0];
#                 popup_67651f4655bd7fc01d218ad848061892.setContent(html_08eb27a6c69a11f9c18bb62474a6
